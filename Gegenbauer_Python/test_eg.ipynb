# %%
from pathlib import Path
import os, sys

repo = Path("/Users/zcq/PaperCode/Recover")
os.chdir(repo)
sys.path.insert(0, str(repo))

# %%
from Gegenbauer_Python.reproduce_chen_shu_2015_examples import main

main([
    "--full",
    "--dps", "40",
    "--output-dir", str(repo / "Gegenbauer_Python/reproductions/chen_shu_2015_full"),
])
# Out:
# Computing Example 6.1, N=40, linear(lambda=2, m=1), paper-opt(lambda=18, m=8)
# Computing Example 6.1, N=80, linear(lambda=5, m=3), paper-opt(lambda=40, m=12)
# Computing Example 6.1, N=160, linear(lambda=10, m=6), paper-opt(lambda=80, m=20)
# Computing Example 6.1, N=320, linear(lambda=20, m=12), paper-opt(lambda=51, m=22)
# Computing Example 6.1, N=640, linear(lambda=40, m=24), paper-opt(lambda=44, m=23)
# Computing Example 6.2, N=40, linear(lambda=5, m=1), paper-opt(lambda=12, m=5)
# Computing Example 6.2, N=80, linear(lambda=10, m=2), paper-opt(lambda=33, m=7)
# Computing Example 6.2, N=160, linear(lambda=20, m=5), paper-opt(lambda=76, m=12)
# Computing Example 6.2, N=320, linear(lambda=40, m=10), paper-opt(lambda=97, m=17)
# Computing Example 6.2, N=640, linear(lambda=80, m=20), paper-opt(lambda=89, m=21)
# Wrote reproduction artifacts to: /Users/zcq/PaperCode/Recover/Gegenbauer_Python/reproductions/chen_shu_2015_full
# 0

# %%
from IPython.display import display, Markdown, Image

out_dir = repo / "Gegenbauer_Python/reproductions/chen_shu_2015_full"

display(Markdown((out_dir / "table_1_example_6_1.md").read_text()))
display(Markdown((out_dir / "table_2_example_6_2.md").read_text()))
display(Image(filename=str(out_dir / "figure_1_examples_6_1_6_2.png")))
# Out:
# # Table 1 reproduction for Example 6.1
#
# | N | linear_lambda | linear_m | computed_linear_Linf | paper_linear_Linf | linear_ratio | computed_order | paper_order | computed_linear_L1_mean | linear_x_at_max | paper_opt_lambda | paper_opt_m | computed_Linf_at_paper_opt_pair | paper_opt_Linf | paper_opt_pair_ratio |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 40 | 2 | 1 | 0.59104992 | 0.591 | 1.0000845 |  |  | 0.25542157 | -1.0 | 18 | 8 | 0.0012064095 | 0.00121 | 0.99703266 |
# | 80 | 5 | 3 | 0.29526459 | 0.295 | 1.0008969 | 1.0013 | 1.00 | 0.067132012 | 1.0 | 40 | 12 | 5.250084e-5 | 5.25e-5 | 1.000016 |
# | 160 | 10 | 6 | 0.015554959 | 0.0156 | 0.99711273 | 4.2466 | 4.25 | 0.0023459744 | 1.0 | 80 | 20 | 1.0179012e-10 | 5.57e-10 | 0.18274707 |
# | 320 | 20 | 12 | 1.334049e-5 | 1.33e-5 | 1.0030444 | 10.187 | 10.19 | 2.4105463e-6 | -1.0 | 51 | 22 | 3.4700121e-11 | 2.75e-11 | 1.2618226 |
# ...
